# %% [markdown]
# DEPENDENCIES

# %%
from bs4 import BeautifulSoup as bs
import requests
import numpy as np
import pandas as pd
import sqlite3
from sqlalchemy import create_engine , inspect
from sqlalchemy.ext.declarative import declarative_base
Base = declarative_base()
from sqlalchemy import Column, Integer, String, Float, DateTime
import datetime as dt

# %% [markdown]
# SOUP EXTRACT

# %%
indeed  = 'https://www.indeed.com/jobs?q=data+analyst&l=#'
response = requests.get(indeed).text

# %%
soup = bs(response, 'html.parser')

# %%
jobCards = soup.find_all('div', class_= 'jobsearch-SerpJobCard')

# %% [markdown]
# TRANSFORM

# %%
#Indeed source
# Loop through returned Indeed soup object and create a list of dicts with values wanted for fields

jobList =[]

for job in jobCards:
    # Error handling
    try:
        # Identify and return title of listing
        title = job.find('a', class_='jobtitle').text.strip()
        company = job.find('span', class_='company').text.strip()
        location = job.find('div', class_ = 'location accessible-contrast-color-location').text.strip()
      

        # Print results only if title, price, and link are available
        if (title and company and location):

           # Dictionary to be inserted into list
            post = {
                'job_title': title,
                'company': company,
                'location': location
            }
            jobList.append(post)
            
    except AttributeError as e:
        pass

# %%
#Indeed List of Dicts create a df
df1 = pd.DataFrame(jobList)

# %%
df1.head(5)
# Out:
#                                        job_title  \
# 0  CCoE CM Cyber Sit. Understanding Data Analyst
# 1                                   Data Analyst
# 2                                   Data Analyst
# 3                               SQL Data Analyst
# 4                               Business Analyst
#
#                                  company  \
# 0                    FITT Scientific LLC
# 1                                RedZone
# 2                                Nemours
# 3  Utility Trailer Manufacturing Company
# 4                             SSR Mining
#
#                                  location
# 0                   Fort Gordon, GA 30905
# 1                             Boulder, CO
# 2  Jacksonville, FL 32099 (Marietta area)
# 3                        Atkins, VA 24311
# 4                               Valmy, NV

# %%
# Import CSV output  from splinter code to a dataframe
df2 = pd.read_csv('Output/glassdoor_jobs.csv') #Remco to populate
df2
# Out:
#                                         job_title  \
# 0     Data Analyst, Customer Experience Analytics
# 1                            Data Quality Analyst
# 2                Data Analyst, Genuine Protection
# 3                Business Data Analyst (must work
# 4   Data Analyst with an Emphasis on Presentation
# 5                             Senior Data Analyst
# 6                                    Data Analyst
# 7                                  Data Analyst I
# 8                          Data Analytics Analyst
# 9                                    Data Analyst
# 10                        Data & Business Analyst
# 11                                   Data Analyst
# 12                                   Data Analyst
# 13                        Salesforce Data Analyst
# 14        Senior Data Analyst, Genuine Protection
# 15                                   Data Analyst
# 16                Product Management Data Analyst
# 17                             BI Data Analyst II
# 18                       Data Engineering Analyst
# 19                                   Data Analyst
# 20                                   Data Analyst
# 21                                   Data Analyst
# 22            DATA INTEGRATION ANALYST - W2 ONLY!
# 23                        Analyst, Data Analytics
# 24                                   Data Analyst
# 25                  Data Driven Solutions Analyst
# 26                      System Data Analyst (EPM)
# 27                                   Data Analyst
# 28                                   Data Analyst
# 29                                   Data Analyst
#
#                             company                           location
# 0                          Autodesk                  San Francisco, CA
# 1                          Autodesk                       Portland, OR
# 2                          Autodesk                           Montreal
# 3                RealTime Solutions                         Becker, MN
# 4                          VS Media  Westlake Village, Los Angeles, CA
# 5                          Autodesk                  San Francisco, CA
# 6          Comprehensive Healthcare                         Yakima, WA
# 7                            Cenlar                          Ewing, NJ
# 8                             Inmar                         Rogers, AR
# 9                  Zelis Healthcare                     Bedminster, NJ
# 10                         PennyMac  Westlake Village, Los Angeles, CA
# 11                         Sedgwick                        Dubuque, IA
# 12                        Trupanion                        Seattle, WA
# 13                          Avalara                             Remote
# 14                         Autodesk                           Montreal
# 15                             DISH                      Englewood, CO
# 16                          HP Inc.                         Spring, TX
# 17                  CHRISTUS Health                         Irving, TX
# 18                COUNTRY Financial                    Bloomington, IL
# 19  CopperPoint Insurance Companies                        Phoenix, AZ
# 20                   Big Huge Games                       Timonium, MD
# 21                    JMH Companies                    New Orleans, LA
# 22               Entelli Consulting                     Schaumburg, IL
# 23                Lincoln Financial                          Dover, NH
# 24                 Allianz Partners                       Richmond, VA
# 25                           Harris                     Saint Paul, MN
# 26            Clinica Family Health                      Lafayette, CO
# 27                      DRB Capital                      Cresskill, NJ
# 28             ReGeneration Schools                        Chicago, IL
# 29                            AIPSO                       Johnston, RI

# %%
# Concat df1 and df2 to df3

df3 = df1.append(df2, sort=False)
df3
# Out:
#                                         job_title  \
# 0   CCoE CM Cyber Sit. Understanding Data Analyst
# 1                                    Data Analyst
# 2                                    Data Analyst
# 3                                SQL Data Analyst
# 4                                Business Analyst
# 5                                    Data Analyst
# 6                          Data Analyst - 9867780
# 7                                    Data Analyst
# 8                        Data Analyst - eCommerce
# 0     Data Analyst, Customer Experience Analytics
# 1                            Data Quality Analyst
# 2                Data Analyst, Genuine Protection
# 3                Business Data Analyst (must work
# 4   Data Analyst with an Emphasis on Presentation
# 5                             Senior Data Analyst
# 6                                    Data Analyst
# 7                                  Data Analyst I
# 8                          Data Analytics Analyst
# 9                                    Data Analyst
# 10                        Data & Business Analyst
# 11                                   Data Analyst
# 12                                   Data Analyst
# 13                        Salesforce Data Analyst
# 14        Senior Data Analyst, Genuine Protection
# 15                                   Data Analyst
# 16                Product Management Data Analyst
# 17                             BI Data Analyst II
# 18                       Data Engineering Analyst
# 19                                   Data Analyst
# 20                                   Data Analyst
# 21                                   Data Analyst
# 22            DATA INTEGRATION ANALYST - W2 ONLY!
# 23                        Analyst, Data Analytics
# 24                                   Data Analyst
# 25                  Data Driven Solutions Analyst
# 26                      System Data Analyst (EPM)
# 27                                   Data Analyst
# 28                                   Data Analyst
# 29                                   Data Analyst
#
#                                   company  \
# 0                     FITT Scientific LLC
# 1                                 RedZone
# 2                                 Nemours
# 3   Utility Trailer Manufacturing Company
# 4                              SSR Mining
# 5                                 Private
# 6                                   Ursus
# 7                              ASPYR, LLC
# 8                                   Uline
# 0                                Autodesk
# 1                                Autodesk
# 2                                Autodesk
# 3                      RealTime Solutions
# 4                                VS Media
# 5                                Autodesk
# 6                Comprehensive Healthcare
# 7                                  Cenlar
# 8                                   Inmar
# 9                        Zelis Healthcare
# 10                               PennyMac
# 11                               Sedgwick
# 12                              Trupanion
# 13                                Avalara
# 14                               Autodesk
# 15                                   DISH
# 16                                HP Inc.
# 17                        CHRISTUS Health
# 18                      COUNTRY Financial
# 19        CopperPoint Insurance Companies
# 20                         Big Huge Games
# 21                          JMH Companies
# 22                     Entelli Consulting
# 23                      Lincoln Financial
# 24                       Allianz Partners
# 25                                 Harris
# 26                  Clinica Family Health
# 27                            DRB Capital
# 28                   ReGeneration Schools
# 29                                  AIPSO
#
#                                              location
# 0                               Fort Gordon, GA 30905
# 1                                         Boulder, CO
# 2              Jacksonville, FL 32099 (Marietta area)
# 3                                    Atkins, VA 24311
# 4                                           Valmy, NV
# 5   Aurora, CO 80011 (Jewell Heights - Hoffman Hei...
# 6                                    McLean, VA 22102
# 7                        Desert Hot Springs, CA 92240
# 8                          Pleasant Prairie, WI 53158
# 0                                   San Francisco, CA
# 1                                        Portland, OR
# 2                                            Montreal
# 3                                          Becker, MN
# 4                   Westlake Village, Los Angeles, CA
# 5                                   San Francisco, CA
# 6                                          Yakima, WA
# 7                                           Ewing, NJ
# 8                                          Rogers, AR
# 9                                      Bedminster, NJ
# 10                  Westlake Village, Los Angeles, CA
# 11                                        Dubuque, IA
# 12                                        Seattle, WA
# 13                                             Remote
# 14                                           Montreal
# 15                                      Englewood, CO
# 16                                         Spring, TX
# 17                                         Irving, TX
# 18                                    Bloomington, IL
# 19                                        Phoenix, AZ
# 20                                       Timonium, MD
# 21                                    New Orleans, LA
# 22                                     Schaumburg, IL
# 23                                          Dover, NH
# 24                                       Richmond, VA
# 25                                     Saint Paul, MN
# 26                                      Lafayette, CO
# 27                                      Cresskill, NJ
# 28                                        Chicago, IL
# 29                                       Johnston, RI

# %% [markdown]
# LOAD

# %%
# Create the posting class (the posting table that will be in the db)
class Posting(Base):
    __tablename__ = 'posting'
    id = Column(Integer, primary_key=True)
    job_title = Column(String(255))
    company = Column(String(255))
    location = Column(String(255))
    timestamp = Column(DateTime())

# %%
# Create a connection to a SQLite database
engine = create_engine('sqlite:///job_postings.db')
conn = engine.connect()
Base.metadata.create_all(engine)  #this should create the table based on the classes defined
from sqlalchemy.orm import Session
session = Session(bind=engine)

# %%
# Iterate over df and add rows as records to table

for i in df3.itertuples():

    try:
        record = Posting(job_title = i.job_title, company = i.company, location = i.location,timestamp = pd.datetime.now().replace(microsecond=0) )
        session.add(record)
        session.commit()
 
    except:
        pass

# %% [markdown]
# TEST

# %%
#Insepect the database
inspector = inspect(engine)
inspector.get_table_names()
# Out:
# ['posting']

# %%
columns = inspector.get_columns('posting')
for column in columns:
    print(column["name"], column["type"])
# Out:
# id INTEGER
# job_title VARCHAR(255)
# company VARCHAR(255)
# location VARCHAR(255)
# timestamp DATETIME

# %%
postings = session.query(Posting)
for job in postings:
  print(job.job_title)
# Out:
# CCoE CM Cyber Sit. Understanding Data Analyst
# Data Analyst
# Data Analyst
# SQL Data Analyst
# Business Analyst
# Data Analyst
# Data Analyst - 9867780
# Data Analyst
# Data Analyst - eCommerce
# Data Analyst, Customer Experience Analytics
# Data Quality Analyst
# Data Analyst, Genuine Protection
# Business Data Analyst (must work
# Data Analyst with an Emphasis on Presentation
# Senior Data Analyst
# Data Analyst
# Data Analyst I
# Data Analytics Analyst
# Data Analyst
# Data & Business Analyst
# Data Analyst
# Data Analyst
# Salesforce Data Analyst
# Senior Data Analyst, Genuine Protection
# Data Analyst
# Product Management Data Analyst
# BI Data Analyst II
# Data Engineering Analyst
# Data Analyst
# Data Analyst
# Data Analyst
# DATA INTEGRATION ANALYST - W2 ONLY!
# Analyst, Data Analytics
# Data Analyst
# Data Driven Solutions Analyst
# System Data Analyst (EPM)
# Data Analyst
# Data Analyst
# Data Analyst

# %% [markdown]
# RESET DataBase

# %%
# Use this to clear out the db when necessary

#Base.metadata.drop_all(engine)

# %% [markdown]
# Troubleshooting Resources:

# %%
# If needed to explore the soup object

#jobCard = soup.find('div', class_= 'jobsearch-SerpJobCard')
#print(jobCard.prettify())
